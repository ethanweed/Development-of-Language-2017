# %%
import os

funcs = '/Users/ethan/Documents/Scripts/Teaching/Development-of-Language/DoL_2017/Functions'
dat = '/Users/ethan/Documents/Scripts/Teaching/Development-of-Language/DoL_2017/Data/Brown/Adam'

os.chdir(funcs)

import getmotchi

# %%
os.chdir(dat)
file = 'adam01.txt'

mother = getmotchi.getmot(file)
child = getmotchi.getchi(file)
both = getmotchi.getmotchi(file)

# %%
both
# Out:
# ['*CHI:play checkers .',
#  '*CHI:big drum .',
#  '*MOT:big drum ',
#  '*CHI:big drum .',
#  '*CHI:big drum .',
#  '*CHI:big drum .',
#  '*CHI:horse .',
#  '*MOT:horse .',
#  '*CHI:who (th)at ',
#  '*MOT:who is that ',
#  '*MOT:those are checkers .',
#  '*CHI:two check .',
#  '*MOT:two checkers (.) yes .',
#  '*CHI:rig horn .',
#  '*CHI:p(l)ay check(ers) .',
#  '*MOT:play checkers ',
#  '*CHI:yep .',
#  '*CHI:big horn .',
#  '*MOT:big horn ',
#  '*CHI:alright look tv .',
#  '*CHI:part .',
#  '*CHI:part .',
#  '*CHI:part .',
#  '*CHI:part .',
#  '*CHI:part .',
#  '*CHI:ge(t) over (.) Mommy .',
#  '*MOT:get over (.) Mommy .',
#  '*CHI:nickel .',
#  '*CHI:nickel .',
#  '*CHI:nickel .',
#  '*CHI:nickel .',
#  '*CHI:shadow .',
#  '*CHI:shadow .',
#  '*CHI:shadow .',
#  '*CHI:shadow .',
#  '*MOT:shadow ',
#  '*CHI:yeah (.) shadow (.) yeah .',
#  '*CHI:shadow (.) funny .',
#  '*CHI:put dirt up .',
#  '*CHI:put dirt up .',
#  '*CHI:put dirt up .',
#  '*CHI:sit dere [: there] .',
# ...

# %%
child
# Out:
# ['*CHI:play checkers .',
#  '*CHI:big drum .',
#  '*CHI:big drum .',
#  '*CHI:big drum .',
#  '*CHI:big drum .',
#  '*CHI:horse .',
#  '*CHI:who (th)at ',
#  '*CHI:two check .',
#  '*CHI:rig horn .',
#  '*CHI:p(l)ay check(ers) .',
#  '*CHI:yep .',
#  '*CHI:big horn .',
#  '*CHI:alright look tv .',
#  '*CHI:part .',
#  '*CHI:part .',
#  '*CHI:part .',
#  '*CHI:part .',
#  '*CHI:part .',
#  '*CHI:ge(t) over (.) Mommy .',
#  '*CHI:nickel .',
#  '*CHI:nickel .',
#  '*CHI:nickel .',
#  '*CHI:nickel .',
#  '*CHI:shadow .',
#  '*CHI:shadow .',
#  '*CHI:shadow .',
#  '*CHI:shadow .',
#  '*CHI:yeah (.) shadow (.) yeah .',
#  '*CHI:shadow (.) funny .',
#  '*CHI:put dirt up .',
#  '*CHI:put dirt up .',
#  '*CHI:put dirt up .',
#  '*CHI:sit dere [: there] .',
#  '*CHI:sit dere [: there] .',
#  '*CHI:sit dere [: there] .',
#  '*CHI:read Shadow .',
#  '*CHI:read Shadow .',
#  '*CHI:read Shadow .',
#  '*CHI:Adam checker .',
#  '*CHI:checker .',
#  '*CHI:horn .',
#  '*CHI:horse .',
# ...

# %%
mother
# Out:
# ['*MOT:big drum ',
#  '*MOT:horse .',
#  '*MOT:who is that ',
#  '*MOT:those are checkers .',
#  '*MOT:two checkers (.) yes .',
#  '*MOT:play checkers ',
#  '*MOT:big horn ',
#  '*MOT:get over (.) Mommy .',
#  '*MOT:shadow ',
#  '*MOT:I like it .',
#  "*MOT:why don't you read Shadow yourself ",
#  "*MOT:that's a terribly small horse for you to ride .",
#  "*MOT:why don't you look at some of the toys in the basket .",
#  '*MOT:want to ',
#  '*MOT:do you want to see what I have ',
#  '*MOT:what is that ',
#  '*MOT:not in your mouth .',
#  '*MOT:let me put them together .',
#  '*MOT:no (.) put floor .',
#  "*MOT:no (.) that's his pencil .",
#  "*MOT:that's not Daddy (.) that's Colin .",
#  "*MOT:I think perhaps he's going back to school .",
#  '*MOT:not on the window sill (.) Adam .',
#  '*MOT:you write on the paper .',
#  '*MOT:my paper .',
#  '*MOT:circus ',
#  "*MOT:sitting in Adam's chair .",
#  "*MOT:why don't you read it to me ",
#  '*MOT:dog .',
#  "*MOT:that's Cathy .",
# ...
